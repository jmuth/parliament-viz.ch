# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
ppl = pd.read_csv('data/people_jonas.csv').set_index('PersonIdCode')

# %%
ppl.head()
# Out:
#               PersonNumber   FirstName                LastName GenderAsString  \
# PersonIdCode
# 2023                   724      Daniel                  Brélaz              m
# 2061                   466       Anita                    Fetz              f
# 2129                   487     Susanne  Leutenegger Oberholzer              f
# 2143                   172        Paul             Rechsteiner              m
# 2147                   173  Maximilian                 Reimann              m
#
#              DateOfBirth  Age  AgeCategory AgeCategoryText NativeLanguage  \
# PersonIdCode
# 2023          04.01.1950   66            5           60-69              F
# 2061          19.03.1957   59            4           50-59              D
# 2129          06.03.1948   68            5           60-69              D
# 2143          26.08.1952   64            5           60-69              D
# 2147          07.05.1942   74            6             70+              D
#
# ...

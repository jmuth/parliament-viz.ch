# %%
ppl = pd.read_csv('data/people_jonas.csv').set_index('PersonIdCode')

# %%
ppl['WordsPerDay'] = ppl.apply(lambda row: row['TotalWords']/row['Seniority'] if (row['Seniority'] > 0) else 0, axis=1)

# %%
ppl
# Out:
#               PersonNumber        FirstName                LastName  \
# PersonIdCode
# 2023                   724           Daniel                  Brélaz
# 2061                   466            Anita                    Fetz
# 2129                   487          Susanne  Leutenegger Oberholzer
# 2143                   172             Paul             Rechsteiner
# 2147                   173       Maximilian                 Reimann
# 2287                    74        Christoph                  Eymann
# 2292                    91           Ulrich            Giezendanner
# 2310                   146             Ueli                  Maurer
# 2323                   214             Luzi                   Stamm
# 2328                   224        Alexander               Tschäppät
# 2370                   305           Didier                Berberat
# 2372                   307             Toni                 Brunner
# 2385                   321            Peter                    Föhn
# ...

# %%
ppl = ppl.sort_values(by='TotalWords', ascending=False)

# %%
ppl
# Out:
#               PersonNumber        FirstName                LastName  \
# PersonIdCode
# 2642                  1161            Alain                  Berset
# 2510                   488            Doris                Leuthard
# 2534                   512        Simonetta               Sommaruga
# 2589                  1116           Didier              Burkhalter
# 2719                  3916           Claude                   Hêche
# 2530                   508        Johann N.        Schneider-Ammann
# 2768                  4055           Stefan                  Engler
# 2575                   825           Hannes                 Germann
# 2741                  4026          Raphaël                   Comte
# 2405                   341          Liliane          Maury Pasquier
# 2724                  3921           Konrad                  Graber
# 2310                   146             Ueli                  Maurer
# 2717                  3914           Robert                  Cramer
# ...

# %%
ppl.WordsPerDay.plot(kind='bar')
plt.show()

# %%
ppl.TotalWords.plot(kind='bar')
plt.show()

# %%
ppl
# Out:
#               PersonNumber     FirstName                LastName  \
# PersonIdCode
# 2510                   488         Doris                Leuthard
# 2534                   512     Simonetta               Sommaruga
# 2642                  1161         Alain                  Berset
# 2589                  1116        Didier              Burkhalter
# 2530                   508     Johann N.        Schneider-Ammann
# 2405                   341       Liliane          Maury Pasquier
# 2061                   466         Anita                    Fetz
# 2575                   825        Hannes                 Germann
# 2310                   146          Ueli                  Maurer
# 2129                   487       Susanne  Leutenegger Oberholzer
# 2501                   477        Claude                  Janiak
# 2561                   540       Filippo                Lombardi
# 2632                  1120         Carlo               Sommaruga
# ...

# %%
ppl.groupby('NativeLanguage').sum()
# Out:
#                 PersonNumber   Age  AgeCategory  FirstSession  Seniority  \
# NativeLanguage
# D                     569777  9376          680        846523     453700
# F                     200173  2980          208        286586     139489
# I                      33963   556           42         53064      29300
# RM                     12325   145           10         14804       4006
# Sk                      3876    49            3          4802       3223
# Tr                      4184    36            2          5002        304
#
#                 TotalWords  WordsPerDay
# NativeLanguage
# D                 13215850  3966.866955
# F                  5951385  1915.903944
# I                   830347   237.529184
# RM                  178645    99.896992
# Sk                   19550     6.065777
# Tr                    7530    24.769737

# %%
13215850/178
# Out:
# 74246.34831460674

# %%
5951385/59
# Out:
# 100870.93220338984
